# %% [markdown]
# # Haar Cascade

# %% [markdown]
# ## 1. Feature Extraction
# extracting each feactures step by step from given image

# %% [markdown]
# ![image.png](attachment:c57b761d-0a88-4398-ade0-0145638c49dd.png)

# %% [markdown]
# 2. Integral image or summarizing the points in image
#     * extracting features and removing useless pixel values and trying to obtain face properties only

# %% [markdown]
# ![image.png](attachment:2d8fbdde-4cfc-4483-bf3c-c5ca985b0729.png)

# %% [markdown]
# to this image
#
# ![image.png](attachment:4244ffff-c094-476f-8df4-1b6501c0ff52.png)

# %% [markdown]
# ## 3. Adaptive boosting (adaboosting)
#     * taking classifier values in each pizel and comparing it with haar cascade fed data and assigning weight
#     * more weight means more penalty as all classifier will be initiated with same weight
#     * reliability is based on the number of weights

# %% [markdown]
# ![image.png](attachment:2c257d95-26c7-45ae-9535-f8cc9062a033.png)

# %% [markdown]
# ## 4.selective cascading
#     * select the passed pisels as the input for next iteration
#     * discard failed pixels combine all inputs to form a face

# %% [markdown]
# ![image.png](attachment:d67e950b-f5d3-48e3-a472-8cdc8dcfec02.png)

# %% [markdown]
# ## 5. Sliding lookup for for coordinates
#     * this is iterative and the algorithm searches for each values in pixel and matches pattern for face pattern and gives output

# %% [markdown]
# ![image.png](attachment:e12ea2b7-1713-415d-8e6b-f0508b6a0259.png)

# %% [markdown]
# same thing gets iterated and refined to sime extent in haar cascade
# # the algorithm for pattern recognition is not discussed and is much complex as i have only discssed overall process without diggin up in the core algorithms

# %% [markdown]
# https://medium.com/analytics-vidhya/haar-cascades-explained-38210e57970d
# ## to have solid grasp of what and how pattern like this gets recognized by haar cascade this lnk will be helpful
